# %%
import numpy as np 
import pandas as pd 
import os
import cv2
import matplotlib.pyplot as plt 
import seaborn as sns
import os
from PIL import Image
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from keras.utils import to_categorical
import pywt
import keras
from keras.layers import Dense, Conv2D
from keras.layers import Flatten
from keras.layers import MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.layers import Dropout
from keras.models import Sequential
from keras import backend as K
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from keras import optimizers
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
penghuni = os.listdir("C:\\Users\\muham\\OneDrive\\Documents\\TA\\images\\train\\Penghuni")
temen1 = os.listdir("C:\\Users\\muham\\OneDrive\\Documents\\TA\\images\\train\\Temen1")
bkn_penghuni = os.listdir("C:\\Users\\muham\\OneDrive\\Documents\\TA\\images\\train\\BukanPenghuni")

# %%
totalaccuracy = []
totalprecision = []
totalrecall = []
totalf1 = []

# %%
def CNNbuild(height, width, classes, channels):
    model = Sequential()
    
    inputShape = (height, width, channels,)
    chanDim = -1
    
    if K.image_data_format() == 'channels_first':
        inputShape = (channels, height, width)
    model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = inputShape))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))

    model.add(Conv2D(32, (3,3), activation = 'relu'))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))

    model.add(Conv2D(32, (3,3), activation = 'relu'))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))

    model.add(Flatten())
    
    model.add(Dense(512, activation = 'relu'))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.5))
    model.add(Dense(classes, activation = 'softmax'))
    
    return model

# %%
def CalcFeatures(img, th):
    sift = cv2.xfeatures2d.SIFT_create(th)
    kp, des = sift.detectAndCompute(img, None)
    return des

# %%
def bag_of_features(features, centres, k = 500):
    vec = np.zeros((1, k))
    for i in range(features.shape[0]):
        feat = features[i]
        diff = np.tile(feat, (k, 1)) - centres
        dist = pow(((pow(diff, 2)).sum(axis = 1)), 0.5)
        idx_dist = dist.argsort()
        idx = idx_dist[0]
        vec[0][idx] += 1
    return vec

# %%
data = []
labels = []
features = []
matrix_zero = np.zeros((81,23))
print(matrix_zero.shape)
# Out:
# (81, 23)

# %%
for i in penghuni:

    image = cv2.imread("C:\\Users\\muham\\OneDrive\\Documents\\TA\\images\\train\\penghuni\\"+i, 0)
    
    dim = (50, 50)
    # image_array = Image.fromarray(image , 'RGB')
    resize_img = cv2.resize(image, dim)
    # resize_img = image_array.resize((50 , 50))

    # Canny Edge Detection
    edges = cv2.Canny(image=resize_img, threshold1=100, threshold2=200) # Canny Edge Detection
    # resize_img = image_array.resize((50 , 50))
    
    resize_img = np.float32(resize_img) / 255.0
    
    # Calculate gradient 
    # gx = cv2.Sobel(resize_img, cv2.CV_32F, 1, 0, ksize=1)
    # gy = cv2.Sobel(resize_img, cv2.CV_32F, 0, 1, ksize=1)
    # mag, angle = cv2.cartToPolar(gx, gy, angleInDegrees=True)

    coeffs2 = pywt.dwt2(resize_img, 'bior1.3')
    LL, (LH, HL, HH) = coeffs2
    
    # print(len(edges))

    a = np.array(edges)
    # b = np.array(mag)
    # ab = np.concatenate((a, b), axis=0)
    # c = np.array(angle)
    # abc = np.concatenate((ab, c), axis=0)
    # d = np.array(gx)
    # abcd = np.concatenate((abc, d), axis=0)
    # e = np.array(gy)
    # abcde = np.concatenate((abcd, e), axis=0)
    v = np.array(LL)
    w = np.array(LH)
    vw = np.concatenate((v, w), axis=0)
    x = np.array(HL)
    vwx = np.concatenate((vw, x), axis=0)
    z = np.array(HH)
    vwxz = np.concatenate((vwx, z), axis=0)
    vwxz_zero = np.concatenate((vwx, matrix_zero), axis=1)
    # print(vwxz_zero.shape)
    # print(len(abcde))
    # data.append(np.array(edges))
    all_feature = np.concatenate((a, vwxz_zero), axis=0)
    # print(all_feature.shape)
    data.append(np.array(all_feature))
    labels.append(0)
    # labels.append(0)

#     print(len(descriptors))

for u in bkn_penghuni:
    
    image = cv2.imread("C:\\Users\\muham\\OneDrive\\Documents\\TA\\images\\train\\BukanPenghuni\\"+u, 0)
    

    dim = (50, 50)
    # image_array = Image.fromarray(image , 'RGB')
    resize_img = cv2.resize(image, dim)
    # resize_img = image_array.resize((50 , 50))

    # Canny Edge Detection
    edges = cv2.Canny(image=resize_img, threshold1=100, threshold2=200) # Canny Edge Detection
    # resize_img = image_array.resize((50 , 50))
    
    resize_img = np.float32(resize_img) / 255.0
    
    # Calculate gradient 
    # gx = cv2.Sobel(resize_img, cv2.CV_32F, 1, 0, ksize=1)
    # gy = cv2.Sobel(resize_img, cv2.CV_32F, 0, 1, ksize=1)
    # mag, angle = cv2.cartToPolar(gx, gy, angleInDegrees=True)

    coeffs2 = pywt.dwt2(resize_img, 'bior1.3')
    LL, (LH, HL, HH) = coeffs2
    # print(len(edges))
    

    a = np.array(edges)
    # b = np.array(mag)
    # ab = np.concatenate((a, b), axis=0)
    # c = np.array(angle)
    # abc = np.concatenate((ab, c), axis=0)
    # d = np.array(gx)
    # abcd = np.concatenate((abc, d), axis=0)
    # e = np.array(gy)
    # abcde = np.concatenate((abcd, e), axis=0)
    v = np.array(LL)
    w = np.array(LH)
    vw = np.concatenate((v, w), axis=0)
    x = np.array(HL)
    vwx = np.concatenate((vw, x), axis=0)
    z = np.array(HH)
    vwxz = np.concatenate((vwx, z), axis=0)
    vwxz_zero = np.concatenate((vwx, matrix_zero), axis=1)
    # print(vwxz_zero.shape)
    # print(len(abcde))
    # data.append(np.array(edges))
    all_feature = np.concatenate((a, vwxz_zero), axis=0)
    data.append(np.array(all_feature))
    # data.append(np.array(vwxz))
    labels.append(1)
    # labels.append(1)

for j in temen1:
    
    image = cv2.imread("C:\\Users\\muham\\OneDrive\\Documents\\TA\\images\\train\\Temen1\\"+j, 0)
    

    dim = (50, 50)
    # image_array = Image.fromarray(image , 'RGB')
    resize_img = cv2.resize(image, dim)
    # resize_img = image_array.resize((50 , 50))

    # Canny Edge Detection
    edges = cv2.Canny(image=resize_img, threshold1=100, threshold2=200) # Canny Edge Detection
    # resize_img = image_array.resize((50 , 50))
    
    resize_img = np.float32(resize_img) / 255.0
    
    # Calculate gradient 
    # gx = cv2.Sobel(resize_img, cv2.CV_32F, 1, 0, ksize=1)
    # gy = cv2.Sobel(resize_img, cv2.CV_32F, 0, 1, ksize=1)
    # mag, angle = cv2.cartToPolar(gx, gy, angleInDegrees=True)

    coeffs2 = pywt.dwt2(resize_img, 'bior1.3')
    LL, (LH, HL, HH) = coeffs2
    # print(len(edges))

    a = np.array(edges)
    # b = np.array(mag)
    # ab = np.concatenate((a, b), axis=0)
    # c = np.array(angle)
    # abc = np.concatenate((ab, c), axis=0)
    # d = np.array(gx)
    # abcd = np.concatenate((abc, d), axis=0)
    # e = np.array(gy)
    # abcde = np.concatenate((abcd, e), axis=0)
    v = np.array(LL)
    w = np.array(LH)
    vw = np.concatenate((v, w), axis=0)
    x = np.array(HL)
    vwx = np.concatenate((vw, x), axis=0)
    z = np.array(HH)
    vwxz = np.concatenate((vwx, z), axis=0)
    vwxz_zero = np.concatenate((vwx, matrix_zero), axis=1)
    # print(vwxz_zero.shape)
    # print(len(abcde))
    # data.append(np.array(edges))
    all_feature = np.concatenate((a, vwxz_zero), axis=0)
    # abcde = abcde[:,27]
    
    # data.append(np.array(edges))
    # all_feature = np.concatenate((abcde, vwxz), axis=0)
    data.append(np.array(all_feature))
    labels.append(2)
    # labels.append(2)

# %%
cells = np.array(data, dtype=object)
labels = np.array(labels)

np.save('Cells' , cells)
np.save('Labels' , labels)

n = np.arange(cells.shape[0])
np.random.shuffle(n)
cells = cells[n]
labels = labels[n]

cells = cells.astype(np.float32)
# cells = np.reshape(cells, (461,15416,1,1))
labels = labels.astype(np.int32)
cells = cells/255
print(cells.shape)
# cells = np.reshape(cells, (250, 50, 50, 1))
# Out:
# (461, 131, 50)

# %%
kf =KFold(n_splits=5, shuffle=True, random_state=42)
cnt = 1
# split()  method generate indices to split data into training and test set.
for train_index, test_index in kf.split(cells, labels):
    print(f'Fold:{cnt}, Train set: {len(train_index)}, Test set:{len(test_index)}')
    print("="*20)
    print("Fold: ", cnt)
    print("="*20)
    cnt +=1

    x_train , x , y_train , y = train_test_split(cells[train_index] , labels[train_index] , 
                                                test_size = 0.2 ,
                                                random_state = 11)

    x_eval ,x_test ,y_eval , y_test = train_test_split(x , y , 
                                                        test_size = 0.5 , 
                                                        random_state = 11)

    y_train = to_categorical(y_train, num_classes = 3)
    y_eval = to_categorical(y_eval, num_classes = 3)
    y_test = to_categorical(y_test, num_classes = 3)

    #instantiate the model
    height = 131
    width = 50
    classes = 3
    channels = 1
    epoch = 75
    model = CNNbuild(height = height, width = width, classes = classes, channels = channels)
    model.summary()

    #compile the model
    model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])

    #fit the model onto the dataset
    # x_train = np.array (x_train)

    h = model.fit(x_train, y_train, epochs = epoch, batch_size = 32,validation_data=(x_eval,y_eval),shuffle=True)

    #evaluate the model on test data
    predictions = model.evaluate(x_test, y_test)
    evaluation = model.evaluate(x_eval, y_eval)

    print(f'LOSS : {evaluation[0]}')
    print(f'ACCURACY : {evaluation[1]}')
    print(f'LOSS : {predictions[0]}')
    print(f'ACCURACY : {predictions[1]}')

    predict_x=model.predict(x_test) 
    yhat_classes=np.argmax(predict_x,axis=1)
    yhat_classes = to_categorical(yhat_classes, num_classes = 3)

    # print("Precision Score : ",precision_score(y_test, y_pred, 
    #                                            pos_label='positive'
    #                                            average='micro'))
    # accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(y_test, yhat_classes)
    print('Accuracy: %f' % accuracy)
    totalaccuracy.append(accuracy)
    # precision tp / (tp + fp)
    precision = precision_score(y_test, yhat_classes, average='macro')
    print('Precision: %f' % precision)
    totalprecision.append(precision)
    # recall: tp / (tp + fn)
    recall = recall_score(y_test, yhat_classes, average='macro')
    print('Recall: %f' % recall)
    totalrecall.append(recall)
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(y_test, yhat_classes, average='macro')
    print('F1 score: %f' % f1)
    totalf1.append(f1)
# Out:
# Fold:1, Train set: 368, Test set:93
# ====================
# Fold:  1
# ====================
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 129, 48, 32)       320
#
#  max_pooling2d_6 (MaxPoolin  (None, 64, 24, 32)        0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 64, 24, 32)        128
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 64, 24, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 62, 22, 32)        9248
#
#  max_pooling2d_7 (MaxPoolin  (None, 31, 11, 32)        0
#  g2D)
#
#  batch_normalization_9 (Bat  (None, 31, 11, 32)        128
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 31, 11, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 29, 9, 32)         9248
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 4, 32)         0
#  g2D)
#
#  batch_normalization_10 (Ba  (None, 14, 4, 32)         128
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 14, 4, 32)         0
#
#  flatten_2 (Flatten)         (None, 1792)              0
#
#  dense_4 (Dense)             (None, 512)               918016
#
#  batch_normalization_11 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 512)               0
#
#  dense_5 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 940803 (3.59 MB)
# Trainable params: 939587 (3.58 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________
# Epoch 1/75
# 10/10 [==============================] - 4s 196ms/step - loss: 1.4019 - accuracy: 0.5170 - val_loss: 1.0186 - val_accuracy: 0.6216
# Epoch 2/75
# 10/10 [==============================] - 2s 172ms/step - loss: 1.1684 - accuracy: 0.6122 - val_loss: 1.0739 - val_accuracy: 0.4054
# Epoch 3/75
# 10/10 [==============================] - 2s 169ms/step - loss: 1.0614 - accuracy: 0.5986 - val_loss: 1.1400 - val_accuracy: 0.3784
# Epoch 4/75
# 10/10 [==============================] - 2s 169ms/step - loss: 1.0234 - accuracy: 0.6327 - val_loss: 1.1210 - val_accuracy: 0.3784
# Epoch 5/75
# 10/10 [==============================] - 2s 184ms/step - loss: 0.1785 - accuracy: 0.9218 - val_loss: 0.8186 - val_accuracy: 0.6757
# Epoch 65/75
# 10/10 [==============================] - 2s 178ms/step - loss: 0.1909 - accuracy: 0.9218 - val_loss: 0.7960 - val_accuracy: 0.7027
# Epoch 66/75
# 10/10 [==============================] - 2s 174ms/step - loss: 0.2102 - accuracy: 0.9184 - val_loss: 0.8060 - val_accuracy: 0.7297
# Epoch 67/75
# 10/10 [==============================] - 2s 185ms/step - loss: 0.2360 - accuracy: 0.9048 - val_loss: 0.8063 - val_accuracy: 0.7027
# Epoch 68/75
# 10/10 [==============================] - 2s 180ms/step - loss: 0.1974 - accuracy: 0.9150 - val_loss: 0.8899 - val_accuracy: 0.7027
# Epoch 69/75
# 10/10 [==============================] - 2s 173ms/step - loss: 0.1719 - accuracy: 0.9184 - val_loss: 0.9089 - val_accuracy: 0.7297
# Epoch 70/75
# 10/10 [==============================] - 2s 187ms/step - loss: 0.1726 - accuracy: 0.9422 - val_loss: 0.8949 - val_accuracy: 0.7027
# Epoch 71/75
# 10/10 [==============================] - 2s 181ms/step - loss: 0.2118 - accuracy: 0.9116 - val_loss: 0.8753 - val_accuracy: 0.7297
# Epoch 72/75
# 10/10 [==============================] - 2s 176ms/step - loss: 0.1752 - accuracy: 0.9184 - val_loss: 0.9648 - val_accuracy: 0.8108
# Epoch 73/75
# 10/10 [==============================] - 2s 193ms/step - loss: 0.1651 - accuracy: 0.9218 - val_loss: 0.8467 - val_accuracy: 0.7027
# Epoch 74/75
# 10/10 [==============================] - 2s 182ms/step - loss: 0.1570 - accuracy: 0.9320 - val_loss: 0.8701 - val_accuracy: 0.7027
# Epoch 75/75
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2143 - accuracy: 0.9014 - val_loss: 0.8925 - val_accuracy: 0.7297
# 2/2 [==============================] - 0s 28ms/step - loss: 1.2355 - accuracy: 0.5946
# 2/2 [==============================] - 0s 14ms/step - loss: 0.8925 - accuracy: 0.7297
# LOSS : 0.8924988508224487
# ACCURACY : 0.7297297120094299
# LOSS : 1.235489845275879
# ACCURACY : 0.5945945978164673
# 2/2 [==============================] - 0s 10ms/step
# Accuracy: 0.594595
# Precision: 0.523077
# Recall: 0.535131
# F1 score: 0.520420
# Fold:2, Train set: 369, Test set:92
# ====================
# Fold:  2
# ====================
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 129, 48, 32)       320
#
#  max_pooling2d_9 (MaxPoolin  (None, 64, 24, 32)        0
#  g2D)
#
#  batch_normalization_12 (Ba  (None, 64, 24, 32)        128
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 64, 24, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 62, 22, 32)        9248
#
#  max_pooling2d_10 (MaxPooli  (None, 31, 11, 32)        0
#  ng2D)
#
#  batch_normalization_13 (Ba  (None, 31, 11, 32)        128
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 31, 11, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 29, 9, 32)         9248
#
#  max_pooling2d_11 (MaxPooli  (None, 14, 4, 32)         0
#  ng2D)
#
#  batch_normalization_14 (Ba  (None, 14, 4, 32)         128
#  tchNormalization)
#
#  dropout_14 (Dropout)        (None, 14, 4, 32)         0
#
#  flatten_3 (Flatten)         (None, 1792)              0
#
#  dense_6 (Dense)             (None, 512)               918016
#
#  batch_normalization_15 (Ba  (None, 512)               2048
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 129, 48, 32)       320
#
#  max_pooling2d_12 (MaxPooli  (None, 64, 24, 32)        0
#  ng2D)
#
#  batch_normalization_16 (Ba  (None, 64, 24, 32)        128
#  tchNormalization)
#
#  dropout_16 (Dropout)        (None, 64, 24, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 62, 22, 32)        9248
#
#  max_pooling2d_13 (MaxPooli  (None, 31, 11, 32)        0
#  ng2D)
#
#  batch_normalization_17 (Ba  (None, 31, 11, 32)        128
#  tchNormalization)
#
#  dropout_17 (Dropout)        (None, 31, 11, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 29, 9, 32)         9248
#
#  max_pooling2d_14 (MaxPooli  (None, 14, 4, 32)         0
#  ng2D)
#
#  batch_normalization_18 (Ba  (None, 14, 4, 32)         128
#  tchNormalization)
#
#  dropout_18 (Dropout)        (None, 14, 4, 32)         0
#
#  flatten_4 (Flatten)         (None, 1792)              0
#
#  dense_8 (Dense)             (None, 512)               918016
#
#  batch_normalization_19 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_9 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 940803 (3.59 MB)
# Trainable params: 939587 (3.58 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________
# Epoch 1/75
# 10/10 [==============================] - 5s 272ms/step - loss: 1.6051 - accuracy: 0.4881 - val_loss: 0.9737 - val_accuracy: 0.6216
# Epoch 2/75
# 10/10 [==============================] - 2s 204ms/step - loss: 1.2600 - accuracy: 0.5559 - val_loss: 0.9809 - val_accuracy: 0.5135
# Epoch 3/75
# 10/10 [==============================] - 2s 191ms/step - loss: 1.2097 - accuracy: 0.5729 - val_loss: 0.9625 - val_accuracy: 0.5135
# Epoch 4/75
# 10/10 [==============================] - 2s 191ms/step - loss: 1.0415 - accuracy: 0.6034 - val_loss: 0.9788 - val_accuracy: 0.5135
# Epoch 5/75
# 10/10 [==============================] - 2s 195ms/step - loss: 0.8563 - accuracy: 0.6814 - val_loss: 1.0223 - val_accuracy: 0.5135
# Epoch 6/75
# 10/10 [==============================] - 2s 187ms/step - loss: 0.8748 - accuracy: 0.6983 - val_loss: 1.0164 - val_accuracy: 0.5135
# Epoch 7/75
# 10/10 [==============================] - 2s 189ms/step - loss: 0.7985 - accuracy: 0.7085 - val_loss: 1.1451 - val_accuracy: 0.5135
# Epoch 8/75
# 10/10 [==============================] - 2s 187ms/step - loss: 0.7530 - accuracy: 0.7356 - val_loss: 1.1935 - val_accuracy: 0.5135
# Epoch 9/75
# 10/10 [==============================] - 2s 182ms/step - loss: 0.7938 - accuracy: 0.7288 - val_loss: 1.3043 - val_accuracy: 0.1622
# Epoch 10/75
# 10/10 [==============================] - 2s 201ms/step - loss: 0.5866 - accuracy: 0.7458 - val_loss: 1.5432 - val_accuracy: 0.1622
# Epoch 11/75
# 10/10 [==============================] - 2s 180ms/step - loss: 0.6385 - accuracy: 0.7356 - val_loss: 1.6439 - val_accuracy: 0.1622
# Epoch 12/75
# 10/10 [==============================] - 2s 184ms/step - loss: 0.6946 - accuracy: 0.7559 - val_loss: 1.5211 - val_accuracy: 0.1622
# Epoch 13/75
# 10/10 [==============================] - 2s 194ms/step - loss: 0.5368 - accuracy: 0.7966 - val_loss: 1.4916 - val_accuracy: 0.1622
# Epoch 14/75
# 2/2 [==============================] - 0s 27ms/step - loss: 0.7118 - accuracy: 0.7027
# LOSS : 0.7117733359336853
# ACCURACY : 0.7027027010917664
# LOSS : 0.9492564797401428
# ACCURACY : 0.6486486196517944
# 2/2 [==============================] - 0s 12ms/step
# Accuracy: 0.648649
# Precision: 0.649573
# Recall: 0.690476
# F1 score: 0.650845
# Fold:4, Train set: 369, Test set:92
# ====================
# Fold:  4
# ====================
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 129, 48, 32)       320
#
#  max_pooling2d_15 (MaxPooli  (None, 64, 24, 32)        0
#  ng2D)
#
#  batch_normalization_20 (Ba  (None, 64, 24, 32)        128
#  tchNormalization)
#
#  dropout_20 (Dropout)        (None, 64, 24, 32)        0
#
#  conv2d_16 (Conv2D)          (None, 62, 22, 32)        9248
#
#  max_pooling2d_16 (MaxPooli  (None, 31, 11, 32)        0
#  ng2D)
#
#  batch_normalization_21 (Ba  (None, 31, 11, 32)        128
#  tchNormalization)
#
#  dropout_21 (Dropout)        (None, 31, 11, 32)        0
#
#  conv2d_17 (Conv2D)          (None, 29, 9, 32)         9248
#
#  max_pooling2d_17 (MaxPooli  (None, 14, 4, 32)         0
#  ng2D)
#
#  batch_normalization_22 (Ba  (None, 14, 4, 32)         128
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 14, 4, 32)         0
#
#  flatten_5 (Flatten)         (None, 1792)              0
#
#  dense_10 (Dense)            (None, 512)               918016
#
#  batch_normalization_23 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_23 (Dropout)        (None, 512)               0
#
#  dense_11 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 940803 (3.59 MB)
# Trainable params: 939587 (3.58 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________
# Epoch 1/75
# 10/10 [==============================] - 4s 199ms/step - loss: 1.4416 - accuracy: 0.4949 - val_loss: 1.0064 - val_accuracy: 0.5135
# Epoch 2/75
# 10/10 [==============================] - 2s 187ms/step - loss: 1.2359 - accuracy: 0.6271 - val_loss: 0.9893 - val_accuracy: 0.4865
# Epoch 3/75
# 10/10 [==============================] - 2s 194ms/step - loss: 1.0238 - accuracy: 0.6068 - val_loss: 0.9917 - val_accuracy: 0.5405
# Epoch 4/75
# 10/10 [==============================] - 2s 192ms/step - loss: 0.9544 - accuracy: 0.6373 - val_loss: 1.0380 - val_accuracy: 0.4054
# Epoch 5/75
# 10/10 [==============================] - 2s 208ms/step - loss: 0.8833 - accuracy: 0.6712 - val_loss: 1.0810 - val_accuracy: 0.3514
# Epoch 6/75
# 10/10 [==============================] - 2s 182ms/step - loss: 0.7169 - accuracy: 0.6983 - val_loss: 1.0975 - val_accuracy: 0.3243
# Epoch 7/75
# 10/10 [==============================] - 2s 201ms/step - loss: 0.7345 - accuracy: 0.7322 - val_loss: 1.0605 - val_accuracy: 0.3514
# Epoch 8/75
# 10/10 [==============================] - 2s 186ms/step - loss: 0.7876 - accuracy: 0.6983 - val_loss: 1.0617 - val_accuracy: 0.4054
# Epoch 9/75
# 10/10 [==============================] - 2s 191ms/step - loss: 0.6942 - accuracy: 0.7627 - val_loss: 1.0911 - val_accuracy: 0.4324
# Epoch 10/75
# 10/10 [==============================] - 2s 209ms/step - loss: 0.5336 - accuracy: 0.7831 - val_loss: 1.1451 - val_accuracy: 0.5135
# Epoch 11/75
# 10/10 [==============================] - 2s 183ms/step - loss: 0.5627 - accuracy: 0.7627 - val_loss: 1.1926 - val_accuracy: 0.5405
# Epoch 12/75
# ...
# Epoch 73/75
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2255 - accuracy: 0.8814 - val_loss: 1.0715 - val_accuracy: 0.6486
# Epoch 74/75
# 10/10 [==============================] - 2s 199ms/step - loss: 0.2303 - accuracy: 0.9017 - val_loss: 1.1318 - val_accuracy: 0.5946
# Epoch 75/75
# 10/10 [==============================] - 2s 198ms/step - loss: 0.2073 - accuracy: 0.9119 - val_loss: 1.1256 - val_accuracy: 0.5676
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6967 - accuracy: 0.7027
# 2/2 [==============================] - 0s 16ms/step - loss: 1.1256 - accuracy: 0.5676
# LOSS : 1.1256077289581299
# ACCURACY : 0.5675675868988037
# LOSS : 0.6966935992240906
# ACCURACY : 0.7027027010917664
# 2/2 [==============================] - 0s 20ms/step
# Accuracy: 0.702703
# Precision: 0.670614
# Recall: 0.676190
# F1 score: 0.672650
# Fold:5, Train set: 369, Test set:92
# ====================
# Fold:  5
# ====================
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 129, 48, 32)       320
#
#  max_pooling2d_18 (MaxPooli  (None, 64, 24, 32)        0
#  ng2D)
#
#  batch_normalization_24 (Ba  (None, 64, 24, 32)        128
#  tchNormalization)
#
#  dropout_24 (Dropout)        (None, 64, 24, 32)        0
#
#  conv2d_19 (Conv2D)          (None, 62, 22, 32)        9248
#
#  max_pooling2d_19 (MaxPooli  (None, 31, 11, 32)        0
#  ng2D)
#
#  batch_normalization_25 (Ba  (None, 31, 11, 32)        128
#  tchNormalization)
#
#  dropout_25 (Dropout)        (None, 31, 11, 32)        0
#
#  conv2d_20 (Conv2D)          (None, 29, 9, 32)         9248
#
#  max_pooling2d_20 (MaxPooli  (None, 14, 4, 32)         0
#  ng2D)
#
#  batch_normalization_26 (Ba  (None, 14, 4, 32)         128
#  tchNormalization)
#
#  dropout_26 (Dropout)        (None, 14, 4, 32)         0
#
#  flatten_6 (Flatten)         (None, 1792)              0
#
#  dense_12 (Dense)            (None, 512)               918016
#
#  batch_normalization_27 (Ba  (None, 512)               2048
#  tchNormalization)
#
#  dropout_27 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 940803 (3.59 MB)
# Trainable params: 939587 (3.58 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________
# Epoch 1/75
# 10/10 [==============================] - 4s 204ms/step - loss: 1.4743 - accuracy: 0.4983 - val_loss: 0.9641 - val_accuracy: 0.5676
# Epoch 2/75
# 10/10 [==============================] - 2s 192ms/step - loss: 1.4020 - accuracy: 0.5593 - val_loss: 0.9138 - val_accuracy: 0.5676
# Epoch 3/75
# 10/10 [==============================] - 2s 193ms/step - loss: 1.1021 - accuracy: 0.6068 - val_loss: 0.9867 - val_accuracy: 0.5676
# Epoch 65/75
# 10/10 [==============================] - 2s 209ms/step - loss: 0.1967 - accuracy: 0.9017 - val_loss: 1.1571 - val_accuracy: 0.6216
# Epoch 66/75
# 10/10 [==============================] - 2s 198ms/step - loss: 0.2396 - accuracy: 0.9085 - val_loss: 1.1856 - val_accuracy: 0.5405
# Epoch 67/75
# 10/10 [==============================] - 2s 205ms/step - loss: 0.2239 - accuracy: 0.8949 - val_loss: 0.9920 - val_accuracy: 0.5405
# Epoch 68/75
# 10/10 [==============================] - 2s 187ms/step - loss: 0.2006 - accuracy: 0.9017 - val_loss: 0.9697 - val_accuracy: 0.5676
# Epoch 69/75
# 10/10 [==============================] - 2s 194ms/step - loss: 0.2134 - accuracy: 0.9186 - val_loss: 0.9798 - val_accuracy: 0.5676
# Epoch 70/75
# 10/10 [==============================] - 2s 204ms/step - loss: 0.2549 - accuracy: 0.8949 - val_loss: 0.9130 - val_accuracy: 0.6216
# Epoch 71/75
# 10/10 [==============================] - 2s 195ms/step - loss: 0.2368 - accuracy: 0.8814 - val_loss: 0.8554 - val_accuracy: 0.6216
# Epoch 72/75
# 10/10 [==============================] - 2s 203ms/step - loss: 0.2081 - accuracy: 0.9186 - val_loss: 0.9855 - val_accuracy: 0.5405
# Epoch 73/75
# 10/10 [==============================] - 2s 192ms/step - loss: 0.2034 - accuracy: 0.9051 - val_loss: 0.9701 - val_accuracy: 0.5405
# Epoch 74/75
# 10/10 [==============================] - 2s 195ms/step - loss: 0.2390 - accuracy: 0.9017 - val_loss: 0.7181 - val_accuracy: 0.7027
# Epoch 75/75
# 10/10 [==============================] - 2s 203ms/step - loss: 0.2232 - accuracy: 0.8983 - val_loss: 0.7690 - val_accuracy: 0.6486
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6196 - accuracy: 0.7027
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7690 - accuracy: 0.6486
# LOSS : 0.7689687609672546
# ACCURACY : 0.6486486196517944
# LOSS : 0.619566023349762
# ACCURACY : 0.7027027010917664
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000015DF2751DC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 25ms/step
# Accuracy: 0.702703
# Precision: 0.692810
# Recall: 0.632540
# F1 score: 0.627933

# %%
print("=" * 20)
print("rata-rata Akurasi: ",sum(totalaccuracy)/len(totalaccuracy))
print("rata-rata Presisi: ",sum(totalprecision)/len(totalprecision))
print("rata-rata Recall: ",sum(totalrecall)/len(totalrecall))
print("rata-rata F1: ",sum(totalf1)/len(totalf1))
# Out:
# ====================
# rata-rata Akurasi:  0.6864864864864865
# rata-rata Presisi:  0.6677006430102405
# rata-rata Recall:  0.6650373482726424
# rata-rata F1:  0.652016491336806

# %%
plt.figure(figsize = (18,8))
plt.plot(range(epoch), h.history['loss'], label = 'Taining Loss')
plt.plot(range(epoch), h.history['val_loss'], label = 'Validation Loss')
plt.xlabel("Number of Epoch's")
plt.ylabel('Loss Value')
plt.title('Training Training & Validation Loss')
plt.legend(loc = "best")

# %%
plt.figure(figsize = (18,8))
plt.plot(range(epoch), h.history['accuracy'], label = 'Taining Accuracy')
plt.plot(range(epoch), h.history['val_accuracy'], label = 'Validation Accuracy')
plt.xlabel("Number of Epoch's")
plt.ylabel('Loss Value')
plt.title('Training Training & Validation Loss')
plt.legend(loc = "best")
